# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../bijlagen/Export ervaringsmonitor kinderafdelingen.csv')
# Out:
# C:\Users\esmee\AppData\Local\Temp\ipykernel_23616\901693795.py:1: DtypeWarning: Columns (18,19,26,53,59,85,86,96,104,130,131,132,133,134,135,136,137,138,139,140,141,142,143,144,145,146,147,148,168) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../bijlagen/Export ervaringsmonitor kinderafdelingen.csv')

# %%
df.head()
# Out:
#    id. Respons-ID submitdate. Datum verzonden  lastpage. Laatste pagina  \
# 0              79         2016-09-01 10:38:01                      16.0
# 1              80         2016-09-01 10:49:05                      16.0
# 2              82         2016-09-01 11:05:56                      16.0
# 3              83                         NaN                      -1.0
# 4              84                         NaN                       9.0
#
#   startlanguage. Begin taal  seed. Plaats startdate. Startdatum  \
# 0                        nl           NaN   2016-09-01 10:27:12
# 1                        nl           NaN   2016-09-01 10:38:53
# 2                        nl           NaN   2016-09-01 10:53:34
# 3                        nl           NaN   2016-09-01 11:48:35
# 4                        nl           NaN   2016-09-01 13:22:23
#
#   datestamp. Datum laatste actie ipaddr. IP-adres  \
# 0            2016-09-01 10:38:01     31.160.78.21
# ...

# %%
# Save all column names to a text file
with open('column_names.txt', 'w') as f:
    for col in df.columns:
        f.write(f"{col}\n")

# %%
# count how many columns there are
len(df.columns)
# Out:
# 243
